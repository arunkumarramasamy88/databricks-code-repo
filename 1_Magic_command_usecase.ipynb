# %% [markdown]
# Task 1 - Document the Notebook Using mark down %md
#
#
# ## Harnessing Magic Commands: A Practical Use Case
# _Exploring Magic Commands in Databricks notebooks to simplify data queries and environment management._
#
# Arunkumar Ramasamy
#
#
# **_Inceptez_WD36_batch First Meetup in  Inceptez Experience center, Velachery, Chennai_**
#
# ![](https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg)

# %%
# %sql
--Task2: Create a volume namely usage_metrics using sql magic command %sql

CREATE VOLUME IF NOT EXISTS workspace.default.usage_metrics;

# %%
# %run "/Workspace/Users/drafttoarun@gmail.com/Local notebook/4_child_nb_dataload"

# %%
# %fs
ls /Volumes/workspace/default/usage_metrics

# %%
# %fs head dbfs:/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv

# %%
# %python

df1 = spark.read.csv("dbfs:/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")

# %%
# %python df1.write.saveAsTable("default.mobile_os_usage")

# %%
# %sql 
select * from default.mobile_os_usage;

# %%
# %python

var1=input("Enter the text to be converted to uppercase:")
print(var1.upper())

# %%
# %pip install pandas

# %%
import pandas as pd

# Read a CSV file (replace the path with your actual file path)
df = pd.read_csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")

# Display the DataFrame
print(df)

# %%
# %sh
echo "Magic commands tasks completed"
