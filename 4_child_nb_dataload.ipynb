# %%
# %py
import requests
tabl_data = requests.get("https://public.tableau.com/app/sample-data/mobile_os_usage.csv")
print(tabl_data.content)
dbutils.fs.put(
    "/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv",
    tabl_data.content.decode("utf-8"),
    True
)
